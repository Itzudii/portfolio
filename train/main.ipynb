# %%
_={
        "id": 809816084,
        "node_id": "R_kgDOMETQFA",
        "name": "Car-Rental-Website-Flask-python",
        "full_name": "Itzudii/Car-Rental-Website-Flask-python",
        "private": False,
        "owner": {
            "login": "Itzudii",
            "id": 145835542,
            "node_id": "U_kgDOCLFGFg",
            "avatar_url": "https://avatars.githubusercontent.com/u/145835542?v=4",
            "gravatar_id": "",
            "url": "https://api.github.com/users/Itzudii",
            "html_url": "https://github.com/Itzudii",
            "followers_url": "https://api.github.com/users/Itzudii/followers",
            "following_url": "https://api.github.com/users/Itzudii/following{/other_user}",
            "gists_url": "https://api.github.com/users/Itzudii/gists{/gist_id}",
            "starred_url": "https://api.github.com/users/Itzudii/starred{/owner}{/repo}",
            "subscriptions_url": "https://api.github.com/users/Itzudii/subscriptions",
            "organizations_url": "https://api.github.com/users/Itzudii/orgs",
            "repos_url": "https://api.github.com/users/Itzudii/repos",
            "events_url": "https://api.github.com/users/Itzudii/events{/privacy}",
            "received_events_url": "https://api.github.com/users/Itzudii/received_events",
            "type": "User",
            "user_view_type": "public",
            "site_admin": False
        },
        "html_url": "https://github.com/Itzudii/Car-Rental-Website-Flask-python",
        "description": None,
        "fork": False,
        "url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python",
        "forks_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/forks",
        "keys_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/keys{/key_id}",
        "collaborators_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/collaborators{/collaborator}",
        "teams_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/teams",
        "hooks_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/hooks",
        "issue_events_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/issues/events{/number}",
        "events_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/events",
        "assignees_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/assignees{/user}",
        "branches_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/branches{/branch}",
        "tags_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/tags",
        "blobs_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/git/blobs{/sha}",
        "git_tags_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/git/tags{/sha}",
        "git_refs_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/git/refs{/sha}",
        "trees_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/git/trees{/sha}",
        "statuses_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/statuses/{sha}",
        "languages_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/languages",
        "stargazers_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/stargazers",
        "contributors_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/contributors",
        "subscribers_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/subscribers",
        "subscription_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/subscription",
        "commits_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/commits{/sha}",
        "git_commits_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/git/commits{/sha}",
        "comments_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/comments{/number}",
        "issue_comment_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/issues/comments{/number}",
        "contents_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/contents/{+path}",
        "compare_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/compare/{base}...{head}",
        "merges_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/merges",
        "archive_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/{archive_format}{/ref}",
        "downloads_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/downloads",
        "issues_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/issues{/number}",
        "pulls_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/pulls{/number}",
        "milestones_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/milestones{/number}",
        "notifications_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/notifications{?since,all,participating}",
        "labels_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/labels{/name}",
        "releases_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/releases{/id}",
        "deployments_url": "https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/deployments",
        "created_at": "2024-06-03T13:58:24Z",
        "updated_at": "2026-03-13T10:49:54Z",
        "pushed_at": "2024-09-18T17:16:50Z",
        "git_url": "git://github.com/Itzudii/Car-Rental-Website-Flask-python.git",
        "ssh_url": "git@github.com:Itzudii/Car-Rental-Website-Flask-python.git",
        "clone_url": "https://github.com/Itzudii/Car-Rental-Website-Flask-python.git",
        "svn_url": "https://github.com/Itzudii/Car-Rental-Website-Flask-python",
        "homepage": "https://rental-green.vercel.app",
        "size": 1484,
        "stargazers_count": 1,
        "watchers_count": 1,
        "language": "HTML",
        "has_issues": True,
        "has_projects": True,
        "has_downloads": True,
        "has_wiki": True,
        "has_pages": False,
        "has_discussions": False,
        "forks_count": 0,
        "mirror_url": None,
        "archived": False,
        "disabled": False,
        "open_issues_count": 0,
        "license": None,
        "allow_forking": True,
        "is_template": False,
        "web_commit_signoff_required": False,
        "has_pull_requests": True,
        "pull_request_creation_policy": "all",
        "topics": [],
        "visibility": "public",
        "forks": 0,
        "open_issues": 0,
        "watchers": 1,
        "default_branch": "main"
    }

# %%
sha = 'a5b08289aba6a93aa5d26bd0ff7c3345922db460'

# %%
owner = 'Itzudii'
repo = 'Car-Rental-Website-Flask-python'

# %%
import requests as req

# %% [markdown]
# ### repos list

# %%
res = req.get('https://api.github.com/users/Itzudii/repos')
res.json()

# %% [markdown]
# ### follower list

# %%
res = req.get('https://api.github.com/users/Itzudii/followers')
res.json()

# %% [markdown]
# ### just like logs list

# %%
res = req.get('https://api.github.com/users/Itzudii/received_events')
res.json()
# Out:
# [{'id': '7368634908',
#   'type': 'WatchEvent',
#   'actor': {'id': 145835542,
#    'login': 'Itzudii',
#    'display_login': 'Itzudii',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Itzudii',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/145835542?'},
#   'repo': {'id': 820362738,
#    'name': 'Itzudii/Library-Management-System-python-',
#    'url': 'https://api.github.com/repos/Itzudii/Library-Management-System-python-'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2026-03-13T10:49:54Z'},
#  {'id': '7368634640',
#   'type': 'WatchEvent',
#   'actor': {'id': 145835542,
#    'login': 'Itzudii',
#    'display_login': 'Itzudii',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Itzudii',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/145835542?'},
#   'repo': {'id': 863711393,
#    'name': 'Itzudii/stock-pridiction-model',
# ...

# %% [markdown]
# ### branch

# %%
res = req.get('https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/branches/main')
res.json()
# Out:
# {'name': 'main',
#  'commit': {'sha': 'a5b08289aba6a93aa5d26bd0ff7c3345922db460',
#   'node_id': 'C_kwDOMETQFNoAKGE1YjA4Mjg5YWJhNmE5M2FhNWQyNmJkMGZmN2MzMzQ1OTIyZGI0NjA',
#   'commit': {'author': {'name': 'Uditya patel',
#     'email': '145835542+Itzudii@users.noreply.github.com',
#     'date': '2024-09-18T17:16:50Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-09-18T17:16:50Z'},
#    'message': 'Update app.py',
#    'tree': {'sha': '776795bdc2046a77920e3d2d8105a2487d751c5e',
#     'url': 'https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/git/trees/776795bdc2046a77920e3d2d8105a2487d751c5e'},
#    'url': 'https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/git/commits/a5b08289aba6a93aa5d26bd0ff7c3345922db460',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
# ...

# %%
res = req.get('https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/tags')
res.json()
# Out:
# []

# %%
res = req.get(f'https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/languages')
res.json()
# Out:
# {'HTML': 24195, 'CSS': 5765, 'Python': 5501}

# %%
res = req.get(f'https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/stargazers')
res.json()
# Out:
# [{'login': 'Itzudii',
#   'id': 145835542,
#   'node_id': 'U_kgDOCLFGFg',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/145835542?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Itzudii',
#   'html_url': 'https://github.com/Itzudii',
#   'followers_url': 'https://api.github.com/users/Itzudii/followers',
#   'following_url': 'https://api.github.com/users/Itzudii/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Itzudii/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Itzudii/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Itzudii/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Itzudii/orgs',
#   'repos_url': 'https://api.github.com/users/Itzudii/repos',
#   'events_url': 'https://api.github.com/users/Itzudii/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Itzudii/received_events',
#   'type': 'User',
# ...

# %%
res = req.get(f'https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/contributors')
res.json()
# Out:
# [{'login': 'Itzudii',
#   'id': 145835542,
#   'node_id': 'U_kgDOCLFGFg',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/145835542?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Itzudii',
#   'html_url': 'https://github.com/Itzudii',
#   'followers_url': 'https://api.github.com/users/Itzudii/followers',
#   'following_url': 'https://api.github.com/users/Itzudii/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Itzudii/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Itzudii/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Itzudii/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Itzudii/orgs',
#   'repos_url': 'https://api.github.com/users/Itzudii/repos',
#   'events_url': 'https://api.github.com/users/Itzudii/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Itzudii/received_events',
#   'type': 'User',
# ...

# %%
res = req.get(f'https://api.github.com/repos/{owner}/{repo}/commits')
res.json()
# Out:
# [{'sha': 'a5b08289aba6a93aa5d26bd0ff7c3345922db460',
#   'node_id': 'C_kwDOMETQFNoAKGE1YjA4Mjg5YWJhNmE5M2FhNWQyNmJkMGZmN2MzMzQ1OTIyZGI0NjA',
#   'commit': {'author': {'name': 'Uditya patel',
#     'email': '145835542+Itzudii@users.noreply.github.com',
#     'date': '2024-09-18T17:16:50Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-09-18T17:16:50Z'},
#    'message': 'Update app.py',
#    'tree': {'sha': '776795bdc2046a77920e3d2d8105a2487d751c5e',
#     'url': 'https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/git/trees/776795bdc2046a77920e3d2d8105a2487d751c5e'},
#    'url': 'https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/git/commits/a5b08289aba6a93aa5d26bd0ff7c3345922db460',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
# ...

# %%
res = req.get(f'https://api.github.com/repos/{owner}/{repo}/git/trees/{sha}?recursive=1')
res.json()
# Out:
# {'sha': 'a5b08289aba6a93aa5d26bd0ff7c3345922db460',
#  'url': 'https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/git/trees/a5b08289aba6a93aa5d26bd0ff7c3345922db460',
#  'tree': [{'path': 'README.md',
#    'mode': '100644',
#    'type': 'blob',
#    'sha': '3caedb940c08ea8ecacb974da15f386aba51cd88',
#    'size': 1861,
#    'url': 'https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/git/blobs/3caedb940c08ea8ecacb974da15f386aba51cd88'},
#   {'path': 'app.py',
#    'mode': '100644',
#    'type': 'blob',
#    'sha': '84835bb75dd29d28c8996942530c47e6ba49bde7',
#    'size': 5501,
#    'url': 'https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/git/blobs/84835bb75dd29d28c8996942530c47e6ba49bde7'},
#   {'path': 'requirements.txt',
#    'mode': '100644',
#    'type': 'blob',
#    'sha': '02e35eb0051b4c1aadca1fcf0e663269f28769df',
#    'size': 108,
# ...

# %%
import requests as req

# %%
res = req.get(f'https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/branches')
res.json()
# Out:
# [{'name': 'main',
#   'commit': {'sha': 'a5b08289aba6a93aa5d26bd0ff7c3345922db460',
#    'url': 'https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/commits/a5b08289aba6a93aa5d26bd0ff7c3345922db460'},
#   'protected': False}]

# %%
_={
        "node_id": "R_kgDOMETQFA",
        "name": "Car-Rental-Website-Flask-python",
        "full_name": "Itzudii/Car-Rental-Website-Flask-python",
        "private": False,
        
        "owner": {
            "avatar_url": "https://avatars.githubusercontent.com/u/145835542?v=4",
        },

        "html_url": "https://github.com/Itzudii/Car-Rental-Website-Flask-python",
        "description": None,

        "created_at": "2024-06-03T13:58:24Z",
        "updated_at": "2026-03-13T10:49:54Z",
        "pushed_at": "2024-09-18T17:16:50Z",

        "git_url": "git://github.com/Itzudii/Car-Rental-Website-Flask-python.git",
        "ssh_url": "git@github.com:Itzudii/Car-Rental-Website-Flask-python.git",
        "homepage": "https://rental-green.vercel.app",
        "size": 1484,
        "stargazers_count": 1,
        "watchers_count": 1,
        "language": "HTML",
    
        "forks_count": 0,
        "topics": [],
        "forks": 0,
        "watchers": 1,
    }

# %%
{'sha': 'a5b08289aba6a93aa5d26bd0ff7c3345922db460',
  'node_id': 'C_kwDOMETQFNoAKGE1YjA4Mjg5YWJhNmE5M2FhNWQyNmJkMGZmN2MzMzQ1OTIyZGI0NjA',
  'commit': {'author': {'name': 'Uditya patel',
    'email': '145835542+Itzudii@users.noreply.github.com',
    'date': '2024-09-18T17:16:50Z'},
   'committer': {'name': 'GitHub',
    'email': 'noreply@github.com',
    'date': '2024-09-18T17:16:50Z'},
   'message': 'Update app.py',
   'tree': {'sha': '776795bdc2046a77920e3d2d8105a2487d751c5e',
    'url': 'https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/git/trees/776795bdc2046a77920e3d2d8105a2487d751c5e'},
   'url': 'https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/git/commits/a5b08289aba6a93aa5d26bd0ff7c3345922db460',
   'comment_count': 0,
   'verification': {'verified': True,
    'reason': 'valid',
    'signature': '-----BEGIN PGP SIGNATURE-----\n\\n4j6UEDhXOYZqLIwssWpf\n=EKP3\n-----END PGP SIGNATURE-----\n',
    'payload': 'tree 776795bdc2046a77920e3d2d8105a2487d751c5e\nparent e777e6c479be8d69928e9551bde5f74b6454bd2b\nauthor Uditya patel <145835542+Itzudii@users.noreply.github.com> 1726679810 +0530\ncommitter GitHub <noreply@github.com> 1726679810 +0530\n\nUpdate app.py',
    'verified_at': '2024-11-26T13:20:13Z'}},
  'url': 'https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/commits/a5b08289aba6a93aa5d26bd0ff7c3345922db460',
  'html_url': 'https://github.com/Itzudii/Car-Rental-Website-Flask-python/commit/a5b08289aba6a93aa5d26bd0ff7c3345922db460',
  'comments_url': 'https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/commits/a5b08289aba6a93aa5d26bd0ff7c3345922db460/comments',
  'author': {'login': 'Itzudii',
   'id': 145835542,
   'node_id': 'U_kgDOCLFGFg',
   'avatar_url': 'https://avatars.githubusercontent.com/u/145835542?v=4',
   'gravatar_id': '',
   'url': 'https://api.github.com/users/Itzudii',
   'html_url': 'https://github.com/Itzudii',
   'followers_url': 'https://api.github.com/users/Itzudii/followers',
   'following_url': 'https://api.github.com/users/Itzudii/following{/other_user}',
   'gists_url': 'https://api.github.com/users/Itzudii/gists{/gist_id}',
   'starred_url': 'https://api.github.com/users/Itzudii/starred{/owner}{/repo}',
   'subscriptions_url': 'https://api.github.com/users/Itzudii/subscriptions',
   'organizations_url': 'https://api.github.com/users/Itzudii/orgs',
   'repos_url': 'https://api.github.com/users/Itzudii/repos',
   'events_url': 'https://api.github.com/users/Itzudii/events{/privacy}',
   'received_events_url': 'https://api.github.com/users/Itzudii/received_events',
   'type': 'User',
   'user_view_type': 'public',
   'site_admin': False},
  'committer': {'login': 'web-flow',
   'id': 19864447,
   'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
   'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
   'gravatar_id': '',
   'url': 'https://api.github.com/users/web-flow',
   'html_url': 'https://github.com/web-flow',
   'followers_url': 'https://api.github.com/users/web-flow/followers',
   'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
   'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
   'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
   'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
   'organizations_url': 'https://api.github.com/users/web-flow/orgs',
   'repos_url': 'https://api.github.com/users/web-flow/repos',
   'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
   'received_events_url': 'https://api.github.com/users/web-flow/received_events',
   'type': 'User',
   'user_view_type': 'public',
   'site_admin': False},
  'parents': [{'sha': 'e777e6c479be8d69928e9551bde5f74b6454bd2b',
    'url': 'https://api.github.com/repos/Itzudii/Car-Rental-Website-Flask-python/commits/e777e6c479be8d69928e9551bde5f74b6454bd2b',
    'html_url': 'https://github.com/Itzudii/Car-Rental-Website-Flask-python/commit/e777e6c479be8d69928e9551bde5f74b6454bd2b'}]},
